# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
pd.options.display.max_rows = 10

# %%
plt.rc('figure', figsize=(10, 6))

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
ax1.hist(np.random.randn(100), bins=20, color='K', alpha=0.3)
# Out:
# (array([ 3.,  3.,  5.,  7.,  9.,  6., 10.,  9., 11.,  8.,  3.,  7.,  6.,
#          5.,  4.,  1.,  1.,  1.,  0.,  1.]),
#  array([-1.90748526, -1.69712175, -1.48675823, -1.27639471, -1.06603119,
#         -0.85566767, -0.64530415, -0.43494064, -0.22457712, -0.0142136 ,
#          0.19614992,  0.40651344,  0.61687696,  0.82724048,  1.03760399,
#          1.24796751,  1.45833103,  1.66869455,  1.87905807,  2.08942159,
#          2.2997851 ]),
#  <a list of 20 Patch objects>)

# %%
plt.close('aa')

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(2, 3)

# %%
fig

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(5000), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('First plot')
ax.set_xlabel('stages')
ax.set({'ylabel': 'test', 'title': 'ttttt'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-2b224f819ce9> in <module>
#       6 ax.set_title('First plot')
#       7 ax.set_xlabel('stages')
# ----> 8 ax.set({'ylabel': 'test', 'title': 'ttttt'})
#
# TypeError: set() takes 1 positional argument but 2 were given

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'r--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'b.', label='three')
ax.legend(loc='best')

# %%
ax.legend?

# %%
from datetime import datetime
data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

# %%
fig, ax = plt.subplots(1, 1)

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'peak of bull market'),
    (datetime(2008, 3, 12), 'bear stearns fails'),
    (datetime(2008, 9, 15), 'lehman bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(data,))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1b51fb19264f> in <module>
#       6     (datetime(2007, 10, 11), 'peak of bull market'),
#       7     (datetime(2008, 3, 12), 'bear stearns fails')
# ----> 8     (datetime(2008, 9, 15), 'lehman bankruptcy')
#       9 ]
#
# TypeError: 'tuple' object is not callable

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3
